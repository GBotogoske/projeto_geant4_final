# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("liquid_argon_rindex.csv", sep=", ")

# converter nm -> eV
df["E"] = 1240.0 / df["x"]
df = df.sort_values("E", ascending=True)

plt.figure(figsize=(6,4))
plt.plot(df["E"], df["y"], marker="o", linestyle="-")
plt.xlabel("Energia [eV]")
plt.ylabel("y (adimensional)")
plt.title("y vs Energia")
plt.grid(True)
plt.show()

df_renamed = df.rename(columns={"y": "r"})
//df_renamed[["E", "r"]].to_json("../configuration/lar_index.json", orient="records", indent=2)
# Out:
# /tmp/ipykernel_9465/970148785.py:4: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv("liquid_argon_rindex.csv", sep=", ")

# %%
import pandas as pd
import matplotlib.pyplot as plt
df3 = pd.read_csv("liquid_argon_scint.csv", sep=", ")

# converter nm -> eV
df3["E"] = 1240.0 / df3["x"]
df3 = df3.sort_values("E", ascending=True)

plt.figure(figsize=(6,4))
plt.plot(df3["E"], df3["y"], marker="o", linestyle="-")
plt.xlabel("Energia [eV]")
plt.ylabel("y (adimensional)")
plt.title("y vs Energia")
plt.grid(True)
plt.show()

df2_renamed = df3.rename(columns={"y": "s"})
df2_renamed[["E", "s"]].to_json("../configuration/lar_scint.json", orient="records", indent=2)
# Out:
# /tmp/ipykernel_1262828/2749025109.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df3 = pd.read_csv("liquid_argon_scint.csv", sep=", ")

# %%
import pandas as pd
import matplotlib.pyplot as plt

df2 = pd.read_csv("liquid_argon_rayleigh.csv", sep=", ")

# converter nm -> eV
df2["E"] = 1240.0 / df2["x"]
df2 = df2.sort_values("E", ascending=True)

plt.figure(figsize=(6,4))
plt.plot(df2["E"], df2["y"], marker="o", linestyle="-")
plt.xlabel("Energia [eV]")
plt.ylabel("y (adimensional)")
plt.title("y vs Energia")
plt.grid(True)
plt.show()

df2_renamed = df2.rename(columns={"y": "l"})
df2_renamed[["E", "l"]].to_json("../configuration/lar_rayleigh.json", orient="records", indent=2)
# Out:
# /home/gabriel/.local/lib/python3.12/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# /home/gabriel/.local/lib/python3.12/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "
# /tmp/ipykernel_1274640/1044189798.py:4: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df2 = pd.read_csv("liquid_argon_rayleigh.csv", sep=", ")
