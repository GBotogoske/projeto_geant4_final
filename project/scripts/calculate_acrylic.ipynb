# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("acrylic_rindex.csv", sep=", ")

# converter nm -> eV
df["E"] = 1240.0 / df["x"]
df = df.sort_values("E", ascending=True)

plt.figure(figsize=(6,4))
plt.plot(df["E"], df["y"], marker="o", linestyle="-")
plt.xlabel("Energia [eV]")
plt.ylabel("y (adimensional)")
plt.title("y vs Energia")
plt.grid(True)
plt.show()

df_renamed = df.rename(columns={"y": "r"})
df_renamed[["E", "r"]].to_json("../configuration/acrylic_index.json", orient="records", indent=2)
# Out:
# /tmp/ipykernel_9644/592224141.py:4: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv("acrylic_rindex.csv", sep=", ")

# %%
df2 = pd.read_csv("acrylic_absorption.csv", sep=", ")

# converter nm -> eV
df2["E"] = 1240.0 / df2["x"]
df2 = df2.sort_values("E", ascending=True)

plt.figure(figsize=(6,4))
plt.plot(df2["E"], df2["y"], marker="o", linestyle="-")
plt.xlabel("Energia [eV]")
plt.ylabel("y (adimensional)")
plt.title("y vs Energia")
plt.grid(True)
plt.show()

df2_renamed = df2.rename(columns={"y": "l"})
df2_renamed[["E", "l"]].to_json("../configuration/acrylic_absorption.json", orient="records", indent=2)
# Out:
# /tmp/ipykernel_9644/822515973.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df2 = pd.read_csv("acrylic_absorption.csv", sep=", ")
