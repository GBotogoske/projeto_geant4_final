# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("sipm_vs.csv", sep=", ")

# converter nm -> eV
df["E"] = 1240.0 / df["x"]
df = df.sort_values("E", ascending=True)

plt.figure(figsize=(6,4))
plt.plot(df["E"], df["y"], marker="o", linestyle="-")
plt.xlabel("Energia [eV]")
plt.ylabel("y (adimensional)")
plt.title("y vs Energia")
plt.grid(True)
plt.show()

df_renamed = df.rename(columns={"y": "p"})
df_renamed[["E", "p"]].to_json("../configuration/efficiency_VIS.json", orient="records", indent=2)
# Out:
# /tmp/ipykernel_95666/2738991123.py:4: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv("sipm_vs.csv", sep=", ")

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("sipm_uv.csv", sep=", ")

# converter nm -> eV
df["E"] = 1240.0 / df["x"]
df = df.sort_values("E", ascending=True)

plt.figure(figsize=(6,4))
plt.plot(df["E"], df["y"], marker="o", linestyle="-")
plt.xlabel("Energia [eV]")
plt.ylabel("y (adimensional)")
plt.title("y vs Energia")
plt.grid(True)
plt.show()

df_renamed = df.rename(columns={"y": "p"})
df_renamed[["E", "p"]].to_json("../configuration/efficiency_UV.json", orient="records", indent=2)
# Out:
# /tmp/ipykernel_95666/3804223151.py:4: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv("sipm_uv.csv", sep=", ")
